# %% [markdown]
# # JobSeekr Fresh - Extract Demo
#
# Every code cell starts with an editable JSON block. Change the JSON in that cell, then run the cell.
#
# Cell flow:
#
# 1. Start browser
# 2. Open jobs page
# 3. Fill keyword and location
# 4. Open and read filters
# 5. Sync filters
# 6. Apply and read listings
# 7. Read pagination
# 8. Close browser

# %%
import importlib
import browser.driver as browser_driver
import core.config as core_config

browser_driver = importlib.reload(browser_driver)
core_config = importlib.reload(core_config)

import json
import time
from pathlib import Path

from browser.driver import build_driver
from core.config import load_app_config
from core.logging import TreeLogger
from storage.embedded_mongo import EmbeddedMongoStore

# Start browser and shared context.
cell_input_json = r'''
{
  "browser": {
    "headless": false,
    "start_maximized": true
  },
  "profile_key": "browser"
}
'''

cell_input = json.loads(cell_input_json)
app_config = load_app_config()
browser_cfg = dict(app_config['profile']['browser'])
browser_cfg.update(cell_input.get('browser', {}))
store = EmbeddedMongoStore(Path(app_config['profile']['mongo_file']))
logger = TreeLogger('extract')
driver = build_driver(browser_cfg)

print(json.dumps({'browser': browser_cfg, 'profile_key': cell_input['profile_key']}, indent=2))
# Out:
# config: dir D:\_Desktop\Projects\Automations prj\Job_search\JobSeekr_fresh\config
# config: load profile.json
# config: load extract.json
# config: load presets.json
# store: open runtime\mongo_store.json
# driver: start
# driver: launch chrome
# driver: ready
# {
#   "browser": {
#     "headless": false,
#     "use_stealth": true,
#     "version_main": 149,
#     "page_load_timeout_seconds": 45,
#     "wait_timeout_seconds": 20,
#     "start_maximized": true,
#     "user_data_dir": "runtime/chrome_user_data"
#   },
#   "profile_key": "browser"
# }

# %%
import importlib
import browser.linkedin_jobs as linkedin_jobs

linkedin_jobs = importlib.reload(linkedin_jobs)

import json

from browser.linkedin_jobs import open_jobs_search_page

# Open the LinkedIn jobs page.
cell_input_json = r'''
{
  "url": "https://www.linkedin.com/jobs/search",
  "delay_seconds": 1.0
}
'''

cell_input = json.loads(cell_input_json)
page_state = open_jobs_search_page(driver, cell_input['url'], delay_seconds=cell_input['delay_seconds'])
print(json.dumps(page_state, indent=2))

# %%
# Run the merged LinkedIn search tool.
import importlib
import browser.linkedin as linkedin

linkedin = importlib.reload(linkedin)

import json

from browser.linkedin import fetch_job_listings

# Edit this JSON before running the cell.
cell_input_json = r'''
{
  "keyword": "software engineering",
  "location": "Dubai",
  "filters": {
    "experience_level": "Entry level"
  },
  "delay_seconds": 1.0,
  "verbose": false
}
'''

cell_input = json.loads(cell_input_json)
search_result = fetch_job_listings(
    driver,
    keyword=cell_input["keyword"],
    location=cell_input["location"],
    filters=cell_input.get("filters"),
    verbose=cell_input.get("verbose", False),
)
print(json.dumps(search_result, indent=2, ensure_ascii=False))

# %%
import importlib
import browser.linkedin_jobs as linkedin_jobs

linkedin_jobs = importlib.reload(linkedin_jobs)

import json

from browser.linkedin_jobs import click_search_button, set_keyword_input, set_location_input

# Fill keyword and location.
cell_input_json = r'''
{
  "keyword": "data analyst",
  "location": "dubai, united arab emirates",
  "delay_seconds": 1.0
}
'''

cell_input = json.loads(cell_input_json)
keyword_state = set_keyword_input(driver, cell_input['keyword'], delay_seconds=cell_input['delay_seconds'])
location_state = set_location_input(driver, cell_input['location'], delay_seconds=cell_input['delay_seconds'])
search_state = click_search_button(driver, delay_seconds=cell_input['delay_seconds'])
print(json.dumps({'keyword': keyword_state, 'location': location_state, 'search': search_state}, indent=2))

# %%
import importlib
import browser.linkedin_jobs as linkedin_jobs

linkedin_jobs = importlib.reload(linkedin_jobs)

import json

from browser.linkedin_jobs import open_all_filters_menu, read_filters_state

# Open filters and read the current state.
cell_input_json = r'''
{
  "open_filters": true,
  "delay_seconds": 1.0
}
'''

cell_input = json.loads(cell_input_json)
if cell_input.get('open_filters'):
    print(json.dumps(open_all_filters_menu(driver, delay_seconds=cell_input['delay_seconds']), indent=2))
    time.sleep(cell_input['delay_seconds'])
current_filters = read_filters_state(driver, ensure_open=not cell_input.get('open_filters'))
print(json.dumps(current_filters, indent=2))

# %%
import importlib
import browser.linkedin_jobs as linkedin_jobs

linkedin_jobs = importlib.reload(linkedin_jobs)

import json

from browser.linkedin_jobs import sync_filters_state

# Sync filter choices.
cell_input_json = r'''
{
  "filter_by": "Jobs",
  "filters": [
    {
      "section": "Sort by",
      "type": "radio",
      "input": "Most recent"
    },
    {
      "section": "Date posted",
      "type": "radio",
      "input": "Past week"
    },
    {
      "section": "Experience level",
      "type": "checkbox",
      "inputs": [
        {"name": "Entry level", "state": true}
      ]
    }
  ],
  "delay_seconds": 0.2
}
'''

cell_input = json.loads(cell_input_json)
synced_filters = sync_filters_state(driver, cell_input, delay_seconds=cell_input['delay_seconds'])
print(json.dumps(synced_filters, indent=2))

# %%
import importlib
import browser.linkedin_jobs as linkedin_jobs

linkedin_jobs = importlib.reload(linkedin_jobs)

import json

from browser.linkedin_jobs import show_results

# Apply filters.
cell_input_json = r'''
{
  "apply_filters": true,
  "delay_seconds": 1.0
}
'''

cell_input = json.loads(cell_input_json)
if cell_input.get('apply_filters'):
    print(json.dumps(show_results(driver, delay_seconds=cell_input['delay_seconds']), indent=2))

# %%
import importlib
import browser.linkedin_jobs as linkedin_jobs

linkedin_jobs = importlib.reload(linkedin_jobs)

import json

from browser.linkedin_jobs import extract_listings

# Read listings.
cell_input_json = r'''
{
  "read_listings": true
}
'''

cell_input = json.loads(cell_input_json)
if cell_input.get('read_listings'):
    listings = extract_listings(driver)
    print(json.dumps(listings, indent=2))

# %%
# Read one listing detail.
import importlib
import browser.linkedin_jobs as linkedin_jobs
import parsers.listing_detail as listing_detail_parser
import stages.listing_detail as listing_detail

linkedin_jobs = importlib.reload(linkedin_jobs)
listing_detail_parser = importlib.reload(listing_detail_parser)
listing_detail = importlib.reload(listing_detail)

import json

from stages.listing_detail import extract_listing_detail

cell_input_json = r'''
{
  "index": 8,
  "delay_seconds": 1.0,
  "delay_jitter": 0.2
}
'''

cell_input = json.loads(cell_input_json)
detail_result = extract_listing_detail(
    driver,
    listings,
    index=cell_input["index"],
    delay_seconds=cell_input["delay_seconds"],
    delay_jitter=cell_input["delay_jitter"],
)
print(json.dumps(detail_result, indent=2, ensure_ascii=False))

# %%
# Convert the current page to markdown.
import importlib
import parsers.page_markdown as page_markdown
import browser.markdown as markdown_tools
page_markdown = importlib.reload(page_markdown)
markdown_tools = importlib.reload(markdown_tools)
import json
from browser.markdown import output_markdown

cell_input_json = r'''
{
  "preview_chars": 600000000
}
'''

cell_input = json.loads(cell_input_json)
markdown_text, interactables = output_markdown(driver)
print(markdown_text[:cell_input["preview_chars"]])
# print(json.dumps(interactables, indent=2, ensure_ascii=False))
# Out:
# ![image] (img1) Learn about DuckDuckGo [[i1]]
#
# [Duck.ai](https://duck.ai/?origin=funnel_home_website) [[i2]]
#
# - Menu [[i3]]
#
# ![image] (img2) Learn about DuckDuckGo [[i4]]
#
# web [[t1]]
#
# funnel_home_website [[t2]]
#
# h_ [[t3]]
#
# 1 [[t4]]
#
# 1 [[t5]]
#
# 1 [[t6]]
#
# Search with DuckDuckGo [[t7]]
#
# Clear search input [[i5]]
#
# Ask Duck.ai [[i6]]
#
# Option+Enter Alt+Enter
#
# Search [disabled] [[i7]]
#
# Search [checked] [[r1]] Search [[i8]] Search
#
# Ask AI [unchecked] [[r2]] Ask AI [[i9]] Ask AI
#
# [Duck.ai](https://duck.ai/?origin=funnel_home_website) [[i10]]
#
# - Menu [[i11]]
#
# # Switch to DuckDuckGo. It’s private![image] (img3) and free!
#
# - ![image] (img4) Add our free extension to block web trackers. Add Extension [[i12]]
# - Best Privacy![image] (img5) || Get our free browser for even more privacy.![image] (img6) || Download Browser [[i13]]
#
# - ![image] (img7) Make DuckDuckGo your default search engine. Set As Default Search [[i14]]
# - Best Privacy![image] (img8) || Get our free browser for even more privacy.![image] (img9) || Download Browser [[i15]]
#
# - ![image] (img10) Make DuckDuckGo your default search engine. Set As Default Search [[i16]]
# - Recommended![image] (img11) Add our free extension to block web trackers. Add Extension [[i17]]
#
# - ![image] (img12) Add our free extension to block web trackers. Add Extension [[i18]]
# - Recommended![image] (img13) Make DuckDuckGo your default search engine. Set As Default Search [[i19]]
#
# - ![image] (img14) Make DuckDuckGo your default search engine. Set As Default Search [[i20]]
#
# Trusted by tens of millions worldwide!
#
# AI Settings [[i21]]
#
# Scroll down to learn more [[i22]]
#
# ## Discover more from DuckDuckGo.
#
# Private Search [[i23]]
#
# Duck.ai [[i24]]
#
# Subscription [[i25]]
#
# Email [[i26]]
#
# # The browser that actively protects your personal information.
#
# ![image] (img15) Download DuckDuckGo for Windows Download DuckDuckGo [[i27]]
#
# Also available on the Microsoft Store
#
# ![Download from Microsoft Store] (img16) || ![Download from Microsoft Store] (img17) || Download from Microsoft Store [[i28]]
#
# Also available on the App Store
#
# ![Download from Mac App Store] (img18) || ![Download from Mac App Store] (img19) || Download from Mac App Store [[i29]]
#
# ![image] (img20)
#
# Evade scams & data-hungry companies Protection [[i30]]
#
# Block most ads & cookie pop-ups Privacy [[i31]]
#
# Search & chat without being tracked Peace of Mind [[i32]]
#
# ## See how DuckDuckGo compares.
#
# div [[i33]]
#
# div [[i34]]
#
# div [[i35]]
#
# div [[i36]]
#
# div [[i37]]
#
# |  |  |  |
# | --- | --- | --- |
# | Search privately by default |  |  |
# | Chat privately with popular AI chatbots (optional) |  |  |
# | Blocks 3rd-party trackers from Facebook, Google, and others |  |  |
# | Blocks targeted ads |  |  |
# | Blocks cookie pop-ups |  |  |
# | Watch YouTube videos without ads |  |  |
# | Securely manages passwords |  |  |
# | Blocks email trackers |  |  |
# | Deletes browsing data with one button |  |  |
# | Removes personal details from sites that sell them |  |  |
# | Helps restore your identity |  |  |
# | Protects your connection with a VPN |  |  |
#
# Included
#
# Limited
#
# Paid
#
# None
#
# Browser comparisons were made with default settings. Information is correct as of December 2025
#
# [Download DuckDuckGo for Windows Download DuckDuckGo](https://duckduckgo.com/windows?origin=funnel_home_website__details) [[i38]]
#
# [Compare More Protections](https://duckduckgo.com/compare-privacy) [[i39]]
#
# ### Protection. Privacy. Peace of mind. Get the browser built for data protection, not data collection.
#
# The DuckDuckGo browser is available on
#
# [Windows](https://duckduckgo.com/windows?origin=funnel_home_website__details) [[i40]]
#
# [Mac](https://duckduckgo.com/mac?origin=funnel_home_website__details) [[i41]]
#
# [Android](https://play.google.com/store/apps/details?id=com.duckduckgo.mobile.android&referrer=origin%3Dfunnel_home_website__details) [[i42]]
#
# [iOS](https://apps.apple.com/app/duckduckgo-privacy-browser/id663592361?platform=iphone&pt=866401&mt=8) [[i43]]
#
# ![image] (img21)
#
# ### Take back control of your personal information.
#
# Hidden trackers lurk on 85% of popular websites. We actively block them by default, helping you evade hackers, scammers, and data-hungry companies.
#
# Goodbye Incognito mode, hello real privacy in every tab [[i44]]
#
# Block 3rd-party trackers from Google, Facebook, and others [[i45]]
#
# Delete all tabs, history, and browsing data in one click [[i46]]
#
# ![image] (img22)
#
# ### Block most ads & cookie pop-ups for fewer interruptions.
#
# Our browser blocks most ads before they even appear, including on videos, so you can enjoy your favorite content with less hassle. We spot cookie pop-ups right away and, where possible, opt you out automatically, so you won’t even see them.
#
# Stop ads following you everywhere [[i47]]
#
# Block annoying cookie pop-ups [[i48]]
#
# Block ads on YouTube [[i49]]
#
# ![image] (img23)
#
# ### Data protection, not data collection.
#
# We believe the best way to protect your data is to stop it from being collected at all. We never track your searches, and our browsing protections help stop other companies from collecting your data.
#
# Search without being tracked [[i50]]
#
# A simple, secure password manager [[i51]]
#
# Chat privately with popular AI chatbots (optional) [[i52]]
#
# ## Don’t just take our word for it.
#
# ![The Verge] (img24) || ![image] (img25) || a solid cross-platform browser that really can keep up with the Chromes and Edges of the world. David Pierce [[i53]]
#
# ![Wired] (img26) || ![image] (img27) || you're getting maximum protection with minimal effort. David Nield [[i54]]
#
# ![Engadget] (img28) || ![image] (img29) || easy and quick to import passwords and bookmarks from other browsers like Chrome. Mariella Moon [[i55]]
#
# ![CNET] (img30) || ![image] (img31) || frees up bandwidth and lets websites load faster. Zachary McAuliffe [[i56]]
#
# ![TechRadar] (img32) || ![image] (img33) || DuckDuckGo is a must-try Desire Athow [[i57]]
#
# ![Apple App Store] (img34) the most intuitive, well laid out, and quick browser I've used. App Store Review [[i58]]
#
# ![Apple App Store] (img35) absolutely love this browser, and cannot imagine using any other again. App Store Review [[i59]]
#
# ![Apple App Store] (img36) I find it faster than Safari, Chrome, and Firefox, and I feel way more protected. App Store Review [[i60]]
#
# ![Google Play Store] (img37) Gives me just the peace of mind that I need. Google Play Review [[i61]]
#
# ![Google Play Store] (img38) it keeps my personal and browsing data away from the big tech companies. Google Play Review [[i62]]
#
# ![Google Play Store] (img39) Pretty much all you could ask for in a browser. Google Play Review [[i63]]
#
# ![The Verge] (img40) || ![image] (img41) || a solid cross-platform browser that really can keep up with the Chromes and Edges of the world. David Pierce [[i64]]
#
# ![Wired] (img42) || ![image] (img43) || you're getting maximum protection with minimal effort. David Nield [[i65]]
#
# ![Engadget] (img44) || ![image] (img45) || easy and quick to import passwords and bookmarks from other browsers like Chrome. Mariella Moon [[i66]]
#
# ![CNET] (img46) || ![image] (img47) || frees up bandwidth and lets websites load faster. Zachary McAuliffe [[i67]]
#
# ![TechRadar] (img48) || ![image] (img49) || DuckDuckGo is a must-try Desire Athow [[i68]]
#
# ![Apple App Store] (img50) the most intuitive, well laid out, and quick browser I've used. App Store Review [[i69]]
#
# ![Apple App Store] (img51) absolutely love this browser, and cannot imagine using any other again. App Store Review [[i70]]
#
# ![Apple App Store] (img52) I find it faster than Safari, Chrome, and Firefox, and I feel way more protected. App Store Review [[i71]]
#
# ![Google Play Store] (img53) Gives me just the peace of mind that I need. Google Play Review [[i72]]
#
# ![Google Play Store] (img54) it keeps my personal and browsing data away from the big tech companies. Google Play Review [[i73]]
#
# ![Google Play Store] (img55) Pretty much all you could ask for in a browser. Google Play Review [[i74]]
#
# ### Trusted by tens of millions worldwide!
#
# - 100% Free
# - 3 Billion Monthly Searches
# - 9 Million Monthly Downloads
#
# ###### Get our free browser today!
#
# [Download DuckDuckGo Browser](https://duckduckgo.com/windows?origin=funnel_home_website__details) [[i75]]
#
# [Download DuckDuckGo on the App Store](https://apps.apple.com/app/duckduckgo-privacy-browser/id663592361?platform=iphone&ct=home-atb-home&pt=866401&mt=8) [[i76]]
#
# 4.8
#
# 2.9 million ratings
#
# [Download DuckDuckGo on Google Play](https://play.google.com/store/apps/details?id=com.duckduckgo.mobile.android&referrer=utm_campaign%3Dhome-atb-home%26origin%3Dfunnel_home_website__details) [[i77]]
#
# 4.7
#
# 2.3 million reviews
#
# ![Dax Magnifying Glass] (img56)
#
# ### Still have questions?
#
# What is DuckDuckGo? [expanded] [[i78]]
#
# At DuckDuckGo, we believe the best way to protect your personal information from hackers, scammers, and privacy-invasive companies is to stop it from being collected at all. That's why millions of people || choose DuckDuckGo over Chrome and other browsers [[i79]] || to search and browse online. Our built-in search engine is like Google but never tracks your searches, and our browser blocks ads, trackers, and cookies that collect your data. It also offers private, useful, and optional AI, including || Duck.ai [[i80]] || , which lets you chat privately with ChatGPT, Claude, and other AIs, all in one place. Oh, and our browser is free. We make money from || privacy-respecting search ads [[i81]] || , not by exploiting your data. Take back control of your personal information with the browser designed for data protection, not data collection. || Learn more [[i82]]
#
# How does DuckDuckGo protect my privacy? [[i83]]
#
# Does DuckDuckGo block all trackers on websites I visit? [[i84]]
#
# How many people use DuckDuckGo? [[i85]]
#
# How does DuckDuckGo make money? [[i86]]
#
# Why use DuckDuckGo instead of Google? [[i87]]
#
# Is Incognito Mode private? [[i88]]
#
# How do DuckDuckGo Search results compare to Google's? [[i89]]
#
# Is DuckDuckGo owned by Google or any other entity? [[i90]]
#
# #### Learn More
#
# - About DuckDuckGo [[i91]]
# - About Our Browser [[i92]]
# - What’s New [[i93]]
# - Compare Privacy [[i94]]
# - Blog [[i95]]
# - Newsletter [[i96]]
# - Podcast [[i97]]
#
# #### Other Resources
#
# - Help [[i98]]
# - Community [[i99]]
# - Careers [[i100]]
# - Privacy Policy [[i101]]
# - Terms of Service [[i102]]
# - Press Kit [[i103]]
# - Advertise on Search [[i104]]
# - Collaborations [[i105]]
#
# #### About DuckDuckGo
#
# At DuckDuckGo, we believe the best way to protect your personal information from hackers, scammers, and privacy-invasive companies is to stop it from being collected at all. That's why millions of people || choose DuckDuckGo over Chrome and other browsers [[i106]] || to search and browse online. Our built-in search engine is like Google but never tracks your searches, and our browser blocks ads, trackers, and cookies that collect your data. It also offers private, useful, and optional AI, including || Duck.ai [[i107]] || , which lets you chat privately with ChatGPT, Claude, and other AIs, all in one place. Oh, and our browser is free. We make money from || privacy-respecting search ads [[i108]] || , not by exploiting your data. Available to download on || Mac [[i109]] || , || Windows [[i110]] || , || iOS [[i111]] || , and || Android [[i112]] .
#
# © 2026 DuckDuckGo [[i113]]
#
# Protection. Privacy. Peace of mind.

# %%
# Test an interaction diff from the current markdown output.
from importlib import import_module, reload

interact_tools = import_module("browser.interact")
interact_tools = reload(interact_tools)

import json

cell_input_json = r'''
{
  "interaction_type": "click",
  "target_id": "i21",
  "delay_seconds": 3
}
'''

cell_input = json.loads(cell_input_json)
interaction_result = interact_tools.interact(
    driver,
    markdown_text,
    interactables,
    cell_input["interaction_type"],
    cell_input["target_id"],
    delay_seconds=cell_input["delay_seconds"],
)
print(json.dumps(interaction_result, indent=2, ensure_ascii=False))
# Out:
# {
#   "status": "success",
#   "interaction_type": "click",
#   "requested_target_id": "i21",
#   "target_id": "i21",
#   "target": {
#     "kind": "interactable",
#     "id": "i21",
#     "order": 21,
#     "type": "link",
#     "text": "Apply now",
#     "anchor_text": "Apply now",
#     "aria_label": "",
#     "role": "",
#     "href": "https://job-boards.eu.greenhouse.io/veeamsoftware/jobs/4885388101#application-form",
#     "value": "",
#     "state": {},
#     "state_text": "",
#     "state_signature": "",
#     "locator": {
#       "kind": "css",
#       "value": "a[href=\"https://job-boards.eu.greenhouse.io/veeamsoftware/jobs/4885388101#application-form\"]"
#     },
#     "ref": "[[i21]]"
#   },
#   "payload": {},
#   "diffs": {
#     "changed": [
#       "[Apply now [[i21]] >>> Google Drive [[i21]]"
#     ],
#     "added": [
#       "![Banner] (img1)",
#       "![Veeam Software Logo] (img2) https://careers.veeam.com/ [[i1]]",
#       "[Back to jobs [[i2]]",
#       "Apply [[i3]]",
#       "[Create alert [[i6]]",
#       "Quick Apply with MyGreenhouse [[i7]]",
#       "First Name * [[i8]]",
#       "Last Name * [[i9]]",
#       "Preferred First Name * [[i10]]",
#       "Email * [[i11]]",
#       "Phone || Country * [[i12]] || Toggle flyout [[i13]] || Select country [[i14]] || Search [[i15]] || Clear search [[i16]] || 244 results found - Afghanistan +93 - Åland Islands +358 - Albania +355 - Algeria +213 - American Samoa +1 - Andorra +376 - Angola +244 - Anguilla +1 - Antigua & Barbuda +1 - Argentina +54 - Armenia +374 - Aruba +297 - Ascension Island +247 - Australia +61 - Austria +43 - Azerbaijan +994 - Bahamas +1 - Bahrain +973 - Bangladesh +880 - Barbados +1 - Belarus +375 - Belgium +32 - Belize +501 - Benin +229 - Bermuda +1 - Bhutan +975 - Bolivia +591 - Bosnia & Herzegovina +387 - Botswana +267 - Brazil +55 - British Indian Ocean Territory +246 - British Virgin Islands +1 - Brunei +673 - Bulgaria +359 - Burkina Faso +226 - Burundi +257 - Cambodia +855 - Cameroon +237 - Canada +1 - Cape Verde +238 - Caribbean Netherlands +599 - Cayman Islands +1 - Central African Republic +236 - Chad +235 - Chile +56 - China +86 - Christmas Island +61 - Cocos (Keeling) Islands +61 - Colombia +57 - Comoros +269 - Congo - Brazzaville +242 - Congo - Kinshasa +243 - Cook Islands +682 - Costa Rica +506 - Côte d’Ivoire +225 - Croatia +385 - Cuba +53 - Curaçao +599 - Cyprus +357 - Czechia +420 - Denmark +45 - Djibouti +253 - Dominica +1 - Dominican Republic +1 - Ecuador +593 - Egypt +20 - El Salvador +503 - Equatorial Guinea +240 - Eritrea +291 - Estonia +372 - Eswatini +268 - Ethiopia +251 - Falkland Islands +500 - Faroe Islands +298 - Fiji +679 - Finland +358 - France +33 - French Guiana +594 - French Polynesia +689 - Gabon +241 - Gambia +220 - Georgia +995 - Germany +49 - Ghana +233 - Gibraltar +350 - Greece +30 - Greenland +299 - Grenada +1 - Guadeloupe +590 - Guam +1 - Guatemala +502 - Guernsey +44 - Guinea +224 - Guinea-Bissau +245 - Guyana +592 - Haiti +509 - Honduras +504 - Hong Kong SAR China +852 - Hungary +36 - Iceland +354 - India +91 - Indonesia +62 - Iran +98 - Iraq +964 - Ireland +353 - Isle of Man +44 - Israel +972 - Italy +39 - Jamaica +1 - Japan +81 - Jersey +44 - Jordan +962 - Kazakhstan +7 - Kenya +254 - Kiribati +686 - Kosovo +383 - Kuwait +965 - Kyrgyzstan +996 - Laos +856 - Latvia +371 - Lebanon +961 - Lesotho +266 - Liberia +231 - Libya +218 - Liechtenstein +423 - Lithuania +370 - Luxembourg +352 - Macao SAR China +853 - Madagascar +261 - Malawi +265 - Malaysia +60 - Maldives +960 - Mali +223 - Malta +356 - Marshall Islands +692 - Martinique +596 - Mauritania +222 - Mauritius +230 - Mayotte +262 - Mexico +52 - Micronesia +691 - Moldova +373 - Monaco +377 - Mongolia +976 - Montenegro +382 - Montserrat +1 - Morocco +212 - Mozambique +258 - Myanmar (Burma) +95 - Namibia +264 - Nauru +674 - Nepal +977 - Netherlands +31 - New Caledonia +687 - New Zealand +64 - Nicaragua +505 - Niger +227 - Nigeria +234 - Niue +683 - Norfolk Island +672 - North Korea +850 - North Macedonia +389 - Northern Mariana Islands +1 - Norway +47 - Oman +968 - Pakistan +92 - Palau +680 - Palestinian Territories +970 - Panama +507 - Papua New Guinea +675 - Paraguay +595 - Peru +51 - Philippines +63 - Poland +48 - Portugal +351 - Puerto Rico +1 - Qatar +974 - Réunion +262 - Romania +40 - Russia +7 - Rwanda +250 - Samoa +685 - San Marino +378 - São Tomé & Príncipe +239 - Saudi Arabia +966 - Senegal +221 - Serbia +381 - Seychelles +248 - Sierra Leone +232 - Singapore +65 - Sint Maarten +1 - Slovakia +421 - Slovenia +386 - Solomon Islands +677 - Somalia +252 - South Africa +27 - South Korea +82 - South Sudan +211 - Spain +34 - Sri Lanka +94 - St. Barthélemy +590 - St. Helena +290 - St. Kitts & Nevis +1 - St. Lucia +1 - St. Martin +590 - St. Pierre & Miquelon +508 - St. Vincent & Grenadines +1 - Sudan +249 - Suriname +597 - Svalbard & Jan Mayen +47 - Sweden +46 - Switzerland +41 - Syria +963 - Taiwan +886 - Tajikistan +992 - Tanzania +255 - Thailand +66 - Timor-Leste +670 - Togo +228 - Tokelau +690 - Tonga +676 - Trinidad & Tobago +1 - Tunisia +216 - Turkey +90 - Turkmenistan +993 - Turks & Caicos Islands +1 - Tuvalu +688 - U.S. Virgin Islands +1  ...
#       "Attach [[i23]]",
#       "Attach [[i24]]",
#       "Dropbox [[i25]]",
#       "Enter manually [[i27]]",
#       "Are you eligible to work in the country where this vacancy is posted? * [[i28]]",
#       "Toggle flyout [[i57]]",
#       "Country of residence * [[i30]]",
#       "Do you require the company to sponsor a visa, work permit, or other authorization for you to work in the country where this role is located? * [[i32]]",
#       "Do you agree to be a part of the talent community for future career opportunities at Veeam? Your information will be retained for up to 2 years. [[i34]]",
#       "Please enter the ZIP code of your primary residence in the United States. * [[i36]]",
#       "To be eligible for this position, your primary residence must be located in the United States. Please indicate the state in which you currently reside. * [[i37]]",
#       "Website / other links [[i39]]",
#       "Have you previously worked for Veeam (including as a contractor or intern)? * [[i40]]",
#       "Do you currently own, operate, or provide services to any other business or organization (e.g., consultancy, freelance, board membership, or contractual engagement)? * [[i42]]",
#       "If yes, please describe the nature of the activity, your role, and whether it may overlap with the responsibilities or interests of Veeam. [[i44]]",
#       "Will you now or in the future require company sponsorship for a visa or work authorization to work in the country where this role is based? * [[i45]]",
#       "What are your annual salary expectations (inclusive of base and bonus)? When determining compensation, Veeam takes into consideration factors such as experience, education, skills, and geographic zone. Offers are typically made below the midpoint of the range * [[i47]]",
#       "Gender [[i48]]",
#       "Are you Hispanic/Latino? [[i50]]",
#       "[Race & Ethnicity Definitions [[i52]]",
#       "Veteran Status [[i53]]",
#       "Completing this form is voluntary, and we hope that you will choose to do so. Your answer is confidential. No one who makes hiring decisions will see it. Your decision to complete the form and your answer will not harm you in any way. If you want to learn more about the law or this form, visit the U.S. Department of Labor’s Office of Federal Contract Compliance Programs (OFCCP) website at www.dol.gov/ofccp [[i55]].",
#       "Disability Status [[i56]]",
#       "By checking this box, I agree to allow Veeam Software to store and process my data for the purpose of considering my eligibility regarding my current application for employment. * [unchecked] [[i58]]",
#       "Submit application [[i59]]",
#       "[https://www.greenhouse.com [[i60]]",
#       "textarea [[i61]]"
#     ],
#     "deleted_element_count": 30
#   },
#   "message": "Clicked i21."
# }

# %%
# Test an interaction diff from the current markdown output.
from importlib import import_module, reload
import json

interact_tools = import_module("browser.interact")
interact_tools = reload(interact_tools)

cell_input_json = r'''
{
  "interaction_type": "input_text",
  "target_id": "t7?value=cheap%20vps",
  "delay_seconds": 1
}
'''

cell_input = json.loads(cell_input_json)
interaction_result = interact_tools.interact(
    driver,
    markdown_text,
    interactables,
    cell_input["interaction_type"],
    cell_input["target_id"],
    delay_seconds=cell_input["delay_seconds"],
)
print(json.dumps(interaction_result, indent=2, ensure_ascii=False))
# Out:
# {
#   "status": "success",
#   "interaction_type": "input_text",
#   "requested_target_id": "t7?value=cheap%20vps",
#   "target_id": "t7",
#   "target": {
#     "kind": "interactable",
#     "id": "t7",
#     "order": 11,
#     "type": "input",
#     "text": "Search with DuckDuckGo",
#     "anchor_text": "Search with DuckDuckGo",
#     "aria_label": "Search with DuckDuckGo",
#     "role": "combobox",
#     "href": "",
#     "value": "",
#     "state": {
#       "input_type": "text"
#     },
#     "state_text": "",
#     "state_signature": "e4a6a0577479b2b4",
#     "locator": {
#       "kind": "css",
#       "value": "#searchbox_input"
#     },
#     "ref": "[[t7]]"
#   },
#   "payload": {
#     "value": "cheap vps"
#   },
#   "diffs": {
#     "changed": [],
#     "added": [
#       "Search [[i7]]",
#       "search [checked] [[r1]] Search [[i8]]",
#       "chat [unchecked] [[r2]] Ask AI [[i9]]",
#       "cheap vps",
#       "cheap vps hosting",
#       "cheap vps india",
#       "cheap vps server",
#       "cheap vps hosting linux",
#       "cheap vps windows",
#       "cheap vps usa"
#     ],
#     "deleted_element_count": 11
#   },
#   "message": "Entered text into t7."
# }

# %%
# Test an interaction diff from the current markdown output.
from importlib import import_module, reload

interact_tools = import_module("browser.interact")
interact_tools = reload(interact_tools)

import json

cell_input_json = r'''
{
  "interaction_type": "input_text",
  "target_id": "i3?value=engineer",
  "delay_seconds": 1
}
'''

cell_input = json.loads(cell_input_json)
interaction_result = interact_tools.interact(
    driver,
    markdown_text,
    interactables,
    cell_input["interaction_type"],
    cell_input["target_id"],
    delay_seconds=cell_input["delay_seconds"],
)
print(json.dumps(interaction_result, indent=2, ensure_ascii=False))
# Out:
# {
#   "status": "success",
#   "interaction_type": "input_text",
#   "requested_target_id": "i3?value=engineer",
#   "target_id": "i3",
#   "target": {
#     "kind": "interactable",
#     "id": "i3",
#     "order": 3,
#     "type": "input",
#     "text": "Search privately",
#     "anchor_text": "Search privately",
#     "aria_label": "",
#     "role": "combobox",
#     "href": "",
#     "value": "",
#     "state": {
#       "input_type": ""
#     },
#     "state_text": "",
#     "state_signature": "",
#     "locator": {
#       "kind": "css",
#       "value": "#search_form_input"
#     },
#     "ref": "[[i3]]"
#   },
#   "payload": {
#     "value": "engineer"
#   },
#   "diffs": {
#     "changed": [],
#     "added": [
#       "clear [[i4]]",
#       "search [[i5]]",
#       "engineer ing",
#       "engineer 's day",
#       "engineer ing drawing",
#       "engineer ing mathematics",
#       "engineer ing khurai thongam leikai rural",
#       "engineer ing moirangkampu",
#       "engineer s india limited",
#       "engineer ing mechanics",
#       "engineer"
#     ],
#     "deleted_element_count": 11
#   },
#   "message": "Entered text into i3."
# }

# %%
import importlib
import browser.linkedin_jobs as linkedin_jobs

linkedin_jobs = importlib.reload(linkedin_jobs)

import json

from browser.linkedin_jobs import get_visible_pages

# Read pagination state.
cell_input_json = r'''
{
  "read_pages": true
}
'''

cell_input = json.loads(cell_input_json)
if cell_input.get('read_pages'):
    pages = get_visible_pages(driver)
    print(json.dumps({'pages': pages['pages']}, indent=2))

# %%
import importlib
import browser.linkedin_jobs as linkedin_jobs

linkedin_jobs = importlib.reload(linkedin_jobs)

import json

from browser.linkedin_jobs import get_current_page, go_to_page

# Go to a page and verify the current page.
cell_input_json = r'''
{
  "page": 2,
  "delay_seconds": 1.0
}
'''

cell_input = json.loads(cell_input_json)
print(json.dumps(go_to_page(driver, cell_input['page'], delay_seconds=cell_input['delay_seconds']), indent=2))
print(json.dumps(get_current_page(driver), indent=2))

# %%
import importlib
import browser.driver as browser_driver

browser_driver = importlib.reload(browser_driver)

import json

from browser.driver import close_driver

# Close browser.
cell_input_json = r'''
{
  "close_driver": true
}
'''

cell_input = json.loads(cell_input_json)
if cell_input.get('close_driver'):
    close_driver(driver)
    print(json.dumps({'status': 'Driver closed.'}, indent=2))
