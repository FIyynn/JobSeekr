# %% [markdown]
# # JobSeekr Fresh - Extract Demo
#
# Every code cell starts with an editable JSON block. Change the JSON in that cell, then run the cell.
#
# Cell flow:
#
# 1. Start browser
# 2. Open jobs page
# 3. Fill keyword and location
# 4. Open and read filters
# 5. Sync filters
# 6. Apply and read listings
# 7. Read pagination
# 8. Close browser

# %%
import importlib
import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / "browser").exists():
    ROOT = ROOT.parent.resolve()
if not (ROOT / "browser").exists():
    raise RuntimeError("Could not locate repo root.")
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

import browser.driver as browser_driver
import core.config as core_config

browser_driver = importlib.reload(browser_driver)
core_config = importlib.reload(core_config)

import json
import time
from pathlib import Path

from browser.driver import build_driver
from core.config import load_app_config
from core.logging import TreeLogger
from storage.embedded_mongo import EmbeddedMongoStore

# Start browser and shared context.
cell_input_json = r'''
{
  "browser": {
    "headless": false,
    "start_maximized": true
  },
  "profile_key": "browser"
}
'''

cell_input = json.loads(cell_input_json)
app_config = load_app_config()
browser_cfg = dict(app_config['profile']['browser'])
browser_cfg.update(cell_input.get('browser', {}))
store = EmbeddedMongoStore(Path(app_config['profile']['mongo_file']))
logger = TreeLogger('extract')
driver = build_driver(browser_cfg)

print(json.dumps({'browser': browser_cfg, 'profile_key': cell_input['profile_key']}, indent=2))
# Out:
# config: dir D:\_Desktop\Projects\Automations prj\Job_search\JobSeekr_fresh\config
# config: load profile.json
# config: load extract.json
# config: load presets.json
# store: open runtime\mongo_store.json
# driver: start
# driver: launch chrome
# driver: ready
# {
#   "browser": {
#     "headless": false,
#     "use_stealth": true,
#     "version_main": 149,
#     "page_load_timeout_seconds": 15,
#     "wait_timeout_seconds": 20,
#     "start_maximized": true,
#     "user_data_dir": "runtime/chrome_user_data"
#   },
#   "profile_key": "browser"
# }

# %%
import importlib
import browser.linkedin_jobs as linkedin_jobs

linkedin_jobs = importlib.reload(linkedin_jobs)

import json

from browser.linkedin_jobs import open_jobs_search_page

# Open the LinkedIn jobs page.
cell_input_json = r'''
{
  "url": "https://www.linkedin.com/jobs/search",
  "delay_seconds": 1.0
}
'''

cell_input = json.loads(cell_input_json)
page_state = open_jobs_search_page(driver, cell_input['url'], delay_seconds=cell_input['delay_seconds'])
print(json.dumps(page_state, indent=2))
# Out:
# page: open https://www.linkedin.com/jobs/search
# page: ready
# {
#   "page_ready": true
# }

# %%
# Run the merged LinkedIn search tool.
import importlib
import browser.linkedin as linkedin

linkedin = importlib.reload(linkedin)

import json

from browser.linkedin import fetch_job_listings

# Edit this JSON before running the cell.
cell_input_json = r'''
{
  "keyword": "software engineering",
  "location": "Dubai",
  "filters": {
    "experience_level": "Entry level"
  },
  "delay_seconds": 1.0,
  "verbose": false
}
'''

cell_input = json.loads(cell_input_json)
search_result = fetch_job_listings(
    driver,
    keyword=cell_input["keyword"],
    location=cell_input["location"],
    filters=cell_input.get("filters"),
    verbose=cell_input.get("verbose", False),
)
print(json.dumps(search_result, indent=2, ensure_ascii=False))
# Out:
# {
#   "status": "success",
#   "keyword": "software engineering",
#   "location": "Dubai",
#   "filter_by": "Jobs",
#   "filters": {
#     "experience_level": "Entry level"
#   },
#   "pages_requested": [
#     1
#   ],
#   "listings": [
#     {
#       "title": "AI Developer - Artificial Intelligence and Data Science Center with verification",
#       "company": "Roads and Transport Authority",
#       "location": "Dubai, United Arab Emirates (On-site)",
#       "link": "https://www.linkedin.com/jobs/view/4429861019/?eBP=CwEAAAGfCsXDADE5VCrpR8epfyStAVKpv6-GU250p_uUcAv3qYE1xTvTVeaacBNj-lXIrIfpVMFRkIIYh7PjlNp8VZTVhtP8auaoXxcFO6bEFkrrx1oDmtnJMDp8VMEi0htYhr8aHoTCQOMfVVJOlGCFiWscTS91petMg1PrIrdflGzB0d6qlPG4T4uIlSA6is-Hacy6W8Ubq6DUd8Pwg_6NS-B2xffLi2aTrrzBcVG59w5GlB_zN4NCi74XoM8b3UBYLzfFcheWnlmYHRBjkDB3i6QAErPJoD-WP6Ve0RxNianRfKbKybpQmyW9bH4iEo6Ek9b13Tq2bJaeV64gQkhsabrXrPIv0ouJKNpz8b8BZCfoD8Cgp6BZhcFysE05D8FzEHv20so4FZS83K_9TiwYP-7MdlVGwwJl02eE6Ql7Dl1BZCffAM6m&refId=MDMR%2BZ9uFHLd92p0Pjykhg%3D%3D&trackingId=VVNpRutDam%2B3TSDbw9cBeg%3D%3D&trk=flagship3_search_srp_jobs",
#       "job_id": "4429861019",
#       "promoted": true,
#       "easy_apply": true,
#       "listed_on": null
#     },
#     {
#       "title": "Teacher of Computer Science & ICT for August 2026 with verification",
#       "company": "International Schools Partnership Limited",
#       "location": "Dubai, Dubai, United Arab Emirates (On-site)",
#       "link": "https://www.linkedin.com/jobs/view/4429649024/?eBP=NOT_ELIGIBLE_FOR_CHARGING&refId=MDMR%2BZ9uFHLd92p0Pjykhg%3D%3D&trackingId=4Qv9uKgr3cI%2BY5IbSHj0CQ%3D%3D&trk=flagship3_search_srp_jobs",
#       "job_id": "4429649024",
#       "promoted": false,
#       "easy_apply": false,
#       "listed_on": "2026-06-21T00:29:21+04:00"
#     }
#   ],
#   "pagination": {
#     "pages": [
#       {
#         "text": "1",
#         "current": true
#       }
#     ],
#     "current_page": "1"
#   },
#   "warnings": [],
#   "log_path": "mock://mongodb/linkedin/fetch_job_listings",
#   "session_state": {
#     "current_url": "https://www.linkedin.com/jobs/search/?currentJobId=4429861019&f_E=2&geoId=106204383&keywords=software%20engineering&origin=JOB_SEARCH_PAGE_JOB_FILTER&refresh=true&sortBy=R",
#     "current_page": "1",
#     "visible_pages": [
#       {
#         "text": "1",
#         "current": true
#       }
#     ],
#     "filter_snapshot": {
#       "filter_by": {
#         "selected": "Jobs",
#         "options": []
#       },
#       "filters": [
#         {
#           "section": "Sort by",
#           "type": "radio",
#           "inputs": [
#             {
#               "name": "Most recent",
#               "state": false
#             },
#             {
#               "name": "Most relevant",
#               "state": true
#             }
#           ]
#         },
#         {
#           "section": "Date posted",
#           "type": "radio",
#           "inputs": [
#             {
#               "name": "Any time",
#               "state": true
#             },
#             {
#               "name": "Past month",
#               "state": false
#             },
#             {
#               "name": "Past week",
#               "state": false
#             },
#             {
#               "name": "Past 24 hours",
#               "state": false
#             }
#           ]
#         },
#         {
#           "section": "Experience level",
#           "type": "checkbox",
#           "inputs": [
#             {
#               "name": "Internship",
#               "state": false
#             },
#             {
#               "name": "Entry level",
#               "state": true
#             },
#             {
#               "name": "Associate",
#               "state": false
#             },
#             {
#               "name": "Mid-Senior level",
#               "state": false
#             },
#             {
#               "name": "Director",
#               "state": false
#             },
#             {
#               "name": "Executive",
#               "state": false
#             }
#           ]
#         },
#         {
#           "section": "Company",
#           "type": "checkbox",
#           "inputs": [
#             {
#               "name": "Fengkai Group Co., Limited",
#               "state": false
#             },
#             {
#               "name": "YO IT Consulting",
#               "state": false
#             },
#             {
#               "name": "Egis",
#               "state": false
#             },
#             {
#               "name": "Ampstek",
#               "state": false
#             },
#             {
#               "name": "Epergne Solutions",
#               "state": false
#             },
#             {
#               "name": "NAGA",
#               "state": false
#             },
#             {
#               "name": "Ministry of Economy & Tourism",
#               "state": false
#             },
#             {
#               "name": "International Schools Partnership Limited",
#               "state": false
#             },
#             {
#               "name": "Canonical",
#               "state": false
#             },
#             {
#               "name": "dubizzle",
#               "state": false
#             }
#           ]
#         },
#         {
#           "section": "Job type",
#           "type": "checkbox",
#           "inputs": [
#             {
#               "name": "Full-time",
#               "state": false
#             },
#             {
#               "name": "Part-time",
#               "state": false
#             },
#             {
#               "name": "Contract",
#               "state": false
#             }
#           ]
#         },
#         {
#           "section": "Remote",
#           "type": "checkbox",
#           "inputs": [
#             {
#               "name": "On-site",
#               "state": false
#             },
#             {
#               "name": "Remote",
#               "state": false
#             },
#             {
#               "name": "Hybrid",
#               "state": false
#             }
#           ]
#         },
#         {
#           "section": "Easy Apply",
#           "type": "switch",
#           "inputs": [
#             {
#               "name": "Toggle Easy Apply filter",
#               "state": false
#             }
#           ]
#         },
#         {
#           "section": "Has verifications",
#           "type": "checkbox",
#           "inputs": [
#             {
#               "name": "Toggle Has verifications filter",
#               "state": false
#             }
#           ]
#         },
#         {
#           "section": "Location",
#           "type": "checkbox",
#           "inputs": [
#             {
#               "name": "Dubai",
#               "state": false
#             }
#           ]
#         },
#         {
#           "section": "Industry",
#           "type": "checkbox",
#           "inputs": [
#             {
#               "name": "Software Development",
#               "state": false
#             },
#             {
#               "name": "Higher Education",
#               "state": false
#             },
#             {
#               "name": "Research Services",
#               "state": false
#             },
#             {
#               "name": "Book and Periodical Publishing",
#               "state": false
#             },
#             {
#               "name": "IT Services and IT Consulting",
#               "state": false
#             },
#             {
#               "name": "Civil Engineering",
#               "state": false
#             },
#             {
#               "name": "Business Consulting and Services",
#               "state": false
#             },
#             {
#               "name": "Transportation, Logistics, Supply Chain and Storage",
#               "state": false
#             },
#             {
#               "name": "Computer and Network Security",
#               "state": false
#             },
#             {
#               "name": "Artificial Intelligence",
#               "state": false
#             }
#           ]
#         },
#         {
#           "section": "Job function",
#           "type": "checkbox",
#           "inputs": [
#             {
#               "name": "Information Technology",
#               "state": false
#             },
#             {
#               "name": "Engineering",
#               "state": false
#             },
#             {
#               "name": "Management",
#               "state": false
#             },
#             {
#               "name": "Quality Assurance",
#               "state": false
#             },
#             {
#               "name": "Research",
#               "state": false
#             },
#             {
#               "name": "Writing/Editing",
#               "state": false
#             },
#             {
#               "name": "Education",
#               "state": false
#             },
#             {
#               "name": "Other",
#               "state": false
#             },
#             {
#               "name": "Project Management",
#               "state": false
#             }
#           ]
#         },
#         {
#           "section": "Title",
#           "type": "checkbox",
#           "inputs": [
#             {
#               "name": "Software Engineering Specialist",
#               "state": false
#             },
#             {
#               "name": "Artificial Intelligence Specialist",
#               "state": false
#             },
#             {
#               "name": "Quality Assurance Lead",
#               "state": false
#             },
#             {
#               "name": "Engineer",
#               "state": false
#             },
#             {
#               "name": "Lead",
#               "state": false
#             },
#             {
#               "name": "Solutions Engineer",
#               "state": false
#             },
#             {
#               "name": "Science Teacher",
#               "state": false
#             },
#             {
#               "name": "Neuroscience Specialist",
#               "state": false
#             },
#             {
#               "name": "Developer",
#               "state": false
#             },
#             {
#               "name": "Data Science Specialist",
#               "state": false
#             }
#           ]
#         },
#         {
#           "section": "Under 10 applicants",
#           "type": "checkbox",
#           "inputs": [
#             {
#               "name": "Toggle Under 10 applicants filter",
#               "state": false
#             }
#           ]
#         },
#         {
#           "section": "In your network",
#           "type": "checkbox",
#           "inputs": [
#             {
#               "name": "Toggle In your network filter",
#               "state": false
#             }
#           ]
#         },
#         {
#           "section": "Fair Chance Employer",
#           "type": "checkbox",
#           "inputs": [
#             {
#               "name": "Toggle Fair Chance Employer filter",
#               "state": false
#             }
#           ]
#         },
#         {
#           "section": "Benefits",
#           "type": "checkbox",
#           "inputs": [
#             {
#               "name": "Medical insurance",
#               "state": false
#             },
#             {
#               "name": "Vision insurance",
#               "state": false
#             },
#             {
#               "name": "Dental insurance",
#               "state": false
#             },
#             {
#               "name": "401(k)",
#               "state": false
#             },
#             {
#               "name": "Pension plan",
#               "state": false
#             },
#             {
#               "name": "Paid maternity leave",
#               "state": false
#             },
#             {
#               "name": "Paid paternity leave",
#               "state": false
#             },
#             {
#               "name": "Commuter benefits",
#               "state": false
#             },
#             {
#               "name": "Student loan assistance",
#               "state": false
#             },
#             {
#               "name": "Tuition assistance",
#               "state": false
#             },
#             {
#               "name": "Disability insurance",
#               "state": false
#             }
#           ]
#         },
#         {
#           "section": "Commitments",
#           "type": "checkbox",
#           "inputs": [
#             {
#               "name": "Career growth and learning",
#               "state": false
#             }
#           ]
#         }
#       ]
#     },
#     "listing_count": 2,
#     "search_task_id": "16d170bb86",
#     "pages_requested": [
#       1
#     ],
#     "pages_fetched": [
#       1
#     ],
#     "visible_unfetched_pages": []
#   },
#   "search_task": {
#     "id": "16d170bb86",
#     "query": "software engineering",
#     "location": "Dubai",
#     "filter_by": "Jobs",
#     "filters": {
#       "experience_level": "Entry level"
#     },
#     "pages_requested": [
#       1
#     ],
#     "pages_fetched": [
#       1
#     ],
#     "listing_count": 2,
#     "visible_unfetched_pages": [],
#     "warnings": []
#   },
#   "dev": {
#     "page_cache": [
#       {
#         "page": 1,
#         "current_page": "1",
#         "visible_pages": [
#           {
#             "text": "1",
#             "current": true
#           }
#         ],
#         "current_url": "https://www.linkedin.com/jobs/search/?currentJobId=4429861019&f_E=2&geoId=106204383&keywords=software%20engineering&origin=JOB_SEARCH_PAGE_JOB_FILTER&refresh=true&sortBy=R",
#         "start_index": 0,
#         "end_index": 1,
#         "listing_count": 2,
#         "listings": [
#           {
#             "title": "AI Developer - Artificial Intelligence and Data Science Center with verification",
#             "company": "Roads and Transport Authority",
#             "location": "Dubai, United Arab Emirates (On-site)",
#             "link": "https://www.linkedin.com/jobs/view/4429861019/?eBP=CwEAAAGfCsXDADE5VCrpR8epfyStAVKpv6-GU250p_uUcAv3qYE1xTvTVeaacBNj-lXIrIfpVMFRkIIYh7PjlNp8VZTVhtP8auaoXxcFO6bEFkrrx1oDmtnJMDp8VMEi0htYhr8aHoTCQOMfVVJOlGCFiWscTS91petMg1PrIrdflGzB0d6qlPG4T4uIlSA6is-Hacy6W8Ubq6DUd8Pwg_6NS-B2xffLi2aTrrzBcVG59w5GlB_zN4NCi74XoM8b3UBYLzfFcheWnlmYHRBjkDB3i6QAErPJoD-WP6Ve0RxNianRfKbKybpQmyW9bH4iEo6Ek9b13Tq2bJaeV64gQkhsabrXrPIv0ouJKNpz8b8BZCfoD8Cgp6BZhcFysE05D8FzEHv20so4FZS83K_9TiwYP-7MdlVGwwJl02eE6Ql7Dl1BZCffAM6m&refId=MDMR%2BZ9uFHLd92p0Pjykhg%3D%3D&trackingId=VVNpRutDam%2B3TSDbw9cBeg%3D%3D&trk=flagship3_search_srp_jobs",
#             "job_id": "4429861019",
#             "promoted": true,
#             "easy_apply": true,
#             "listed_on": null
#           },
#           {
#             "title": "Teacher of Computer Science & ICT for August 2026 with verification",
#             "company": "International Schools Partnership Limited",
#             "location": "Dubai, Dubai, United Arab Emirates (On-site)",
#             "link": "https://www.linkedin.com/jobs/view/4429649024/?eBP=NOT_ELIGIBLE_FOR_CHARGING&refId=MDMR%2BZ9uFHLd92p0Pjykhg%3D%3D&trackingId=4Qv9uKgr3cI%2BY5IbSHj0CQ%3D%3D&trk=flagship3_search_srp_jobs",
#             "job_id": "4429649024",
#             "promoted": false,
#             "easy_apply": false,
#             "listed_on": "2026-06-21T00:29:21+04:00"
#           }
#         ]
#       }
#     ],
#     "search_task": {
#       "id": "16d170bb86",
#       "keyword": "software engineering",
#       "location": "Dubai",
#       "filter_by": "Jobs",
#       "filters": {
#         "experience_level": "Entry level"
#       },
#       "pages_requested": [
#         1
#       ],
#       "pages_fetched": [
#         1
#       ],
#       "listing_count": 2,
#       "visible_unfetched_pages": [],
#       "warnings": [],
#       "page_cache": [
#         {
#           "page": 1,
#           "current_page": "1",
#           "visible_pages": [
#             {
#               "text": "1",
#               "current": true
#             }
#           ],
#           "current_url": "https://www.linkedin.com/jobs/search/?currentJobId=4429861019&f_E=2&geoId=106204383&keywords=software%20engineering&origin=JOB_SEARCH_PAGE_JOB_FILTER&refresh=true&sortBy=R",
#           "start_index": 0,
#           "end_index": 1,
#           "listing_count": 2,
#           "listings": [
#             {
#               "title": "AI Developer - Artificial Intelligence and Data Science Center with verification",
#               "company": "Roads and Transport Authority",
#               "location": "Dubai, United Arab Emirates (On-site)",
#               "link": "https://www.linkedin.com/jobs/view/4429861019/?eBP=CwEAAAGfCsXDADE5VCrpR8epfyStAVKpv6-GU250p_uUcAv3qYE1xTvTVeaacBNj-lXIrIfpVMFRkIIYh7PjlNp8VZTVhtP8auaoXxcFO6bEFkrrx1oDmtnJMDp8VMEi0htYhr8aHoTCQOMfVVJOlGCFiWscTS91petMg1PrIrdflGzB0d6qlPG4T4uIlSA6is-Hacy6W8Ubq6DUd8Pwg_6NS-B2xffLi2aTrrzBcVG59w5GlB_zN4NCi74XoM8b3UBYLzfFcheWnlmYHRBjkDB3i6QAErPJoD-WP6Ve0RxNianRfKbKybpQmyW9bH4iEo6Ek9b13Tq2bJaeV64gQkhsabrXrPIv0ouJKNpz8b8BZCfoD8Cgp6BZhcFysE05D8FzEHv20so4FZS83K_9TiwYP-7MdlVGwwJl02eE6Ql7Dl1BZCffAM6m&refId=MDMR%2BZ9uFHLd92p0Pjykhg%3D%3D&trackingId=VVNpRutDam%2B3TSDbw9cBeg%3D%3D&trk=flagship3_search_srp_jobs",
#               "job_id": "4429861019",
#               "promoted": true,
#               "easy_apply": true,
#               "listed_on": null
#             },
#             {
#               "title": "Teacher of Computer Science & ICT for August 2026 with verification",
#               "company": "International Schools Partnership Limited",
#               "location": "Dubai, Dubai, United Arab Emirates (On-site)",
#               "link": "https://www.linkedin.com/jobs/view/4429649024/?eBP=NOT_ELIGIBLE_FOR_CHARGING&refId=MDMR%2BZ9uFHLd92p0Pjykhg%3D%3D&trackingId=4Qv9uKgr3cI%2BY5IbSHj0CQ%3D%3D&trk=flagship3_search_srp_jobs",
#               "job_id": "4429649024",
#               "promoted": false,
#               "easy_apply": false,
#               "listed_on": "2026-06-21T00:29:21+04:00"
#             }
#           ]
#         }
#       ]
#     }
#   },
#   "logs": {
#     "stage": "linkedin_fetch_job_listings",
#     "events": [
#       {
#         "level": "info",
#         "message": "Open LinkedIn jobs search page",
#         "details": [
#           "log_path=mock://mongodb/linkedin/fetch_job_listings"
#         ],
#         "children": []
#       },
#       {
#         "level": "info",
#         "message": "Set keyword",
#         "details": [
#           "keyword=software engineering"
#         ],
#         "children": []
#       },
#       {
#         "level": "info",
#         "message": "Set location",
#         "details": [
#           "location=Dubai"
#         ],
#         "children": []
#       },
#       {
#         "level": "info",
#         "message": "Click search",
#         "children": []
#       },
#       {
#         "level": "info",
#         "message": "Open filters panel",
#         "children": []
#       },
#       {
#         "level": "info",
#         "message": "Sync filters",
#         "children": []
#       },
#       {
#         "level": "info",
#         "message": "Show results",
#         "children": []
#       }
#     ]
#   },
#   "filter_snapshot": {
#     "filter_by": {
#       "selected": "Jobs",
#       "options": []
#     },
#     "filters": [
#       {
#         "section": "Sort by",
#         "type": "radio",
#         "inputs": [
#           {
#             "name": "Most recent",
#             "state": false
#           },
#           {
#             "name": "Most relevant",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Date posted",
#         "type": "radio",
#         "inputs": [
#           {
#             "name": "Any time",
#             "state": false
#           },
#           {
#             "name": "Past month",
#             "state": false
#           },
#           {
#             "name": "Past week",
#             "state": false
#           },
#           {
#             "name": "Past 24 hours",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Experience level",
#         "type": "checkbox",
#         "inputs": [
#           {
#             "name": "Internship",
#             "state": false
#           },
#           {
#             "name": "Entry level",
#             "state": false
#           },
#           {
#             "name": "Associate",
#             "state": false
#           },
#           {
#             "name": "Mid-Senior level",
#             "state": false
#           },
#           {
#             "name": "Director",
#             "state": false
#           },
#           {
#             "name": "Executive",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Company",
#         "type": "checkbox",
#         "inputs": [
#           {
#             "name": "DataAnnotation",
#             "state": false
#           },
#           {
#             "name": "Walmart",
#             "state": false
#           },
#           {
#             "name": "McDonald's",
#             "state": false
#           },
#           {
#             "name": "Inside Higher Ed",
#             "state": false
#           },
#           {
#             "name": "Advance Auto Parts",
#             "state": false
#           },
#           {
#             "name": "Panda Restaurant Group",
#             "state": false
#           },
#           {
#             "name": "PwC",
#             "state": false
#           },
#           {
#             "name": "Epic",
#             "state": false
#           },
#           {
#             "name": "Cracker Barrel",
#             "state": false
#           },
#           {
#             "name": "Hibbett",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Job type",
#         "type": "checkbox",
#         "inputs": [
#           {
#             "name": "Full-time",
#             "state": false
#           },
#           {
#             "name": "Part-time",
#             "state": false
#           },
#           {
#             "name": "Contract",
#             "state": false
#           },
#           {
#             "name": "Temporary",
#             "state": false
#           },
#           {
#             "name": "Volunteer",
#             "state": false
#           },
#           {
#             "name": "Internship",
#             "state": false
#           },
#           {
#             "name": "Other",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Remote",
#         "type": "checkbox",
#         "inputs": [
#           {
#             "name": "On-site",
#             "state": false
#           },
#           {
#             "name": "Remote",
#             "state": false
#           },
#           {
#             "name": "Hybrid",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Easy Apply",
#         "type": "switch",
#         "inputs": [
#           {
#             "name": "Toggle Easy Apply filter",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Has verifications",
#         "type": "checkbox",
#         "inputs": [
#           {
#             "name": "Toggle Has verifications filter",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Location",
#         "type": "checkbox",
#         "inputs": [
#           {
#             "name": "New York, NY",
#             "state": false
#           },
#           {
#             "name": "Houston, TX",
#             "state": false
#           },
#           {
#             "name": "Chicago, IL",
#             "state": false
#           },
#           {
#             "name": "Dallas, TX",
#             "state": false
#           },
#           {
#             "name": "Los Angeles, CA",
#             "state": false
#           },
#           {
#             "name": "Atlanta, GA",
#             "state": false
#           },
#           {
#             "name": "San Francisco, CA",
#             "state": false
#           },
#           {
#             "name": "Austin, TX",
#             "state": false
#           },
#           {
#             "name": "Boston, MA",
#             "state": false
#           },
#           {
#             "name": "Philadelphia, PA",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Industry",
#         "type": "checkbox",
#         "inputs": [
#           {
#             "name": "Hospitals and Health Care",
#             "state": false
#           },
#           {
#             "name": "Retail",
#             "state": false
#           },
#           {
#             "name": "IT Services and IT Consulting",
#             "state": false
#           },
#           {
#             "name": "Software Development",
#             "state": false
#           },
#           {
#             "name": "Construction",
#             "state": false
#           },
#           {
#             "name": "Financial Services",
#             "state": false
#           },
#           {
#             "name": "Restaurants",
#             "state": false
#           },
#           {
#             "name": "Business Consulting and Services",
#             "state": false
#           },
#           {
#             "name": "Motor Vehicle Manufacturing",
#             "state": false
#           },
#           {
#             "name": "Accounting",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Job function",
#         "type": "checkbox",
#         "inputs": [
#           {
#             "name": "Management",
#             "state": false
#           },
#           {
#             "name": "Manufacturing",
#             "state": false
#           },
#           {
#             "name": "Health Care Provider",
#             "state": false
#           },
#           {
#             "name": "Sales",
#             "state": false
#           },
#           {
#             "name": "Information Technology",
#             "state": false
#           },
#           {
#             "name": "Other",
#             "state": false
#           },
#           {
#             "name": "Business Development",
#             "state": false
#           },
#           {
#             "name": "Engineering",
#             "state": false
#           },
#           {
#             "name": "Education",
#             "state": false
#           },
#           {
#             "name": "Finance",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Title",
#         "type": "checkbox",
#         "inputs": [
#           {
#             "name": "Salesperson",
#             "state": false
#           },
#           {
#             "name": "Mechanical Technician",
#             "state": false
#           },
#           {
#             "name": "Software Engineer",
#             "state": false
#           },
#           {
#             "name": "Driver",
#             "state": false
#           },
#           {
#             "name": "Chef",
#             "state": false
#           },
#           {
#             "name": "Food and Beverage Server",
#             "state": false
#           },
#           {
#             "name": "Supply Chain Associate",
#             "state": false
#           },
#           {
#             "name": "Store Assistant",
#             "state": false
#           },
#           {
#             "name": "Retail Specialist",
#             "state": false
#           },
#           {
#             "name": "Parts Specialist",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Under 10 applicants",
#         "type": "checkbox",
#         "inputs": [
#           {
#             "name": "Toggle Under 10 applicants filter",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "In your network",
#         "type": "checkbox",
#         "inputs": [
#           {
#             "name": "Toggle In your network filter",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Fair Chance Employer",
#         "type": "checkbox",
#         "inputs": [
#           {
#             "name": "Toggle Fair Chance Employer filter",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Salary",
#         "type": "radio",
#         "inputs": [
#           {
#             "name": "$40,000+",
#             "state": false
#           },
#           {
#             "name": "$60,000+",
#             "state": false
#           },
#           {
#             "name": "$80,000+",
#             "state": false
#           },
#           {
#             "name": "$100,000+",
#             "state": false
#           },
#           {
#             "name": "$120,000+",
#             "state": false
#           },
#           {
#             "name": "$140,000+",
#             "state": false
#           },
#           {
#             "name": "$160,000+",
#             "state": false
#           },
#           {
#             "name": "$180,000+",
#             "state": false
#           },
#           {
#             "name": "$200,000+",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Benefits",
#         "type": "checkbox",
#         "inputs": [
#           {
#             "name": "Medical insurance",
#             "state": false
#           },
#           {
#             "name": "Vision insurance",
#             "state": false
#           },
#           {
#             "name": "Dental insurance",
#             "state": false
#           },
#           {
#             "name": "401(k)",
#             "state": false
#           },
#           {
#             "name": "Pension plan",
#             "state": false
#           },
#           {
#             "name": "Paid maternity leave",
#             "state": false
#           },
#           {
#             "name": "Paid paternity leave",
#             "state": false
#           },
#           {
#             "name": "Commuter benefits",
#             "state": false
#           },
#           {
#             "name": "Student loan assistance",
#             "state": false
#           },
#           {
#             "name": "Tuition assistance",
#             "state": false
#           },
#           {
#             "name": "Disability insurance",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Commitments",
#         "type": "checkbox",
#         "inputs": [
#           {
#             "name": "Career growth and learning",
#             "state": false
#           },
#           {
#             "name": "Diversity, equity, and inclusion",
#             "state": false
#           },
#           {
#             "name": "Environmental sustainability",
#             "state": false
#           },
#           {
#             "name": "Social impact",
#             "state": false
#           },
#           {
#             "name": "Work-life balance",
#             "state": false
#           }
#         ]
#       }
#     ]
#   },
#   "filter_snapshot_after_sync": {
#     "filter_by": {
#       "selected": "Jobs",
#       "options": []
#     },
#     "filters": [
#       {
#         "section": "Sort by",
#         "type": "radio",
#         "inputs": [
#           {
#             "name": "Most recent",
#             "state": false
#           },
#           {
#             "name": "Most relevant",
#             "state": true
#           }
#         ]
#       },
#       {
#         "section": "Date posted",
#         "type": "radio",
#         "inputs": [
#           {
#             "name": "Any time",
#             "state": true
#           },
#           {
#             "name": "Past month",
#             "state": false
#           },
#           {
#             "name": "Past week",
#             "state": false
#           },
#           {
#             "name": "Past 24 hours",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Experience level",
#         "type": "checkbox",
#         "inputs": [
#           {
#             "name": "Internship",
#             "state": false
#           },
#           {
#             "name": "Entry level",
#             "state": true
#           },
#           {
#             "name": "Associate",
#             "state": false
#           },
#           {
#             "name": "Mid-Senior level",
#             "state": false
#           },
#           {
#             "name": "Director",
#             "state": false
#           },
#           {
#             "name": "Executive",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Company",
#         "type": "checkbox",
#         "inputs": [
#           {
#             "name": "Fengkai Group Co., Limited",
#             "state": false
#           },
#           {
#             "name": "YO IT Consulting",
#             "state": false
#           },
#           {
#             "name": "Egis",
#             "state": false
#           },
#           {
#             "name": "Ampstek",
#             "state": false
#           },
#           {
#             "name": "Epergne Solutions",
#             "state": false
#           },
#           {
#             "name": "NAGA",
#             "state": false
#           },
#           {
#             "name": "Ministry of Economy & Tourism",
#             "state": false
#           },
#           {
#             "name": "International Schools Partnership Limited",
#             "state": false
#           },
#           {
#             "name": "Canonical",
#             "state": false
#           },
#           {
#             "name": "dubizzle",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Job type",
#         "type": "checkbox",
#         "inputs": [
#           {
#             "name": "Full-time",
#             "state": false
#           },
#           {
#             "name": "Part-time",
#             "state": false
#           },
#           {
#             "name": "Contract",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Remote",
#         "type": "checkbox",
#         "inputs": [
#           {
#             "name": "On-site",
#             "state": false
#           },
#           {
#             "name": "Remote",
#             "state": false
#           },
#           {
#             "name": "Hybrid",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Easy Apply",
#         "type": "switch",
#         "inputs": [
#           {
#             "name": "Toggle Easy Apply filter",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Has verifications",
#         "type": "checkbox",
#         "inputs": [
#           {
#             "name": "Toggle Has verifications filter",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Location",
#         "type": "checkbox",
#         "inputs": [
#           {
#             "name": "Dubai",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Industry",
#         "type": "checkbox",
#         "inputs": [
#           {
#             "name": "Software Development",
#             "state": false
#           },
#           {
#             "name": "Higher Education",
#             "state": false
#           },
#           {
#             "name": "Research Services",
#             "state": false
#           },
#           {
#             "name": "Book and Periodical Publishing",
#             "state": false
#           },
#           {
#             "name": "IT Services and IT Consulting",
#             "state": false
#           },
#           {
#             "name": "Civil Engineering",
#             "state": false
#           },
#           {
#             "name": "Business Consulting and Services",
#             "state": false
#           },
#           {
#             "name": "Transportation, Logistics, Supply Chain and Storage",
#             "state": false
#           },
#           {
#             "name": "Computer and Network Security",
#             "state": false
#           },
#           {
#             "name": "Artificial Intelligence",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Job function",
#         "type": "checkbox",
#         "inputs": [
#           {
#             "name": "Information Technology",
#             "state": false
#           },
#           {
#             "name": "Engineering",
#             "state": false
#           },
#           {
#             "name": "Management",
#             "state": false
#           },
#           {
#             "name": "Quality Assurance",
#             "state": false
#           },
#           {
#             "name": "Research",
#             "state": false
#           },
#           {
#             "name": "Writing/Editing",
#             "state": false
#           },
#           {
#             "name": "Education",
#             "state": false
#           },
#           {
#             "name": "Other",
#             "state": false
#           },
#           {
#             "name": "Project Management",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Title",
#         "type": "checkbox",
#         "inputs": [
#           {
#             "name": "Software Engineering Specialist",
#             "state": false
#           },
#           {
#             "name": "Artificial Intelligence Specialist",
#             "state": false
#           },
#           {
#             "name": "Quality Assurance Lead",
#             "state": false
#           },
#           {
#             "name": "Engineer",
#             "state": false
#           },
#           {
#             "name": "Lead",
#             "state": false
#           },
#           {
#             "name": "Solutions Engineer",
#             "state": false
#           },
#           {
#             "name": "Science Teacher",
#             "state": false
#           },
#           {
#             "name": "Neuroscience Specialist",
#             "state": false
#           },
#           {
#             "name": "Developer",
#             "state": false
#           },
#           {
#             "name": "Data Science Specialist",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Under 10 applicants",
#         "type": "checkbox",
#         "inputs": [
#           {
#             "name": "Toggle Under 10 applicants filter",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "In your network",
#         "type": "checkbox",
#         "inputs": [
#           {
#             "name": "Toggle In your network filter",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Fair Chance Employer",
#         "type": "checkbox",
#         "inputs": [
#           {
#             "name": "Toggle Fair Chance Employer filter",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Benefits",
#         "type": "checkbox",
#         "inputs": [
#           {
#             "name": "Medical insurance",
#             "state": false
#           },
#           {
#             "name": "Vision insurance",
#             "state": false
#           },
#           {
#             "name": "Dental insurance",
#             "state": false
#           },
#           {
#             "name": "401(k)",
#             "state": false
#           },
#           {
#             "name": "Pension plan",
#             "state": false
#           },
#           {
#             "name": "Paid maternity leave",
#             "state": false
#           },
#           {
#             "name": "Paid paternity leave",
#             "state": false
#           },
#           {
#             "name": "Commuter benefits",
#             "state": false
#           },
#           {
#             "name": "Student loan assistance",
#             "state": false
#           },
#           {
#             "name": "Tuition assistance",
#             "state": false
#           },
#           {
#             "name": "Disability insurance",
#             "state": false
#           }
#         ]
#       },
#       {
#         "section": "Commitments",
#         "type": "checkbox",
#         "inputs": [
#           {
#             "name": "Career growth and learning",
#             "state": false
#           }
#         ]
#       }
#     ]
#   }
# }

# %%
import importlib
import browser.linkedin_jobs as linkedin_jobs

linkedin_jobs = importlib.reload(linkedin_jobs)

import json

from browser.linkedin_jobs import click_search_button, set_keyword_input, set_location_input

# Fill keyword and location.
cell_input_json = r'''
{
  "keyword": "data analyst",
  "location": "dubai, united arab emirates",
  "delay_seconds": 1.0
}
'''

cell_input = json.loads(cell_input_json)
keyword_state = set_keyword_input(driver, cell_input['keyword'], delay_seconds=cell_input['delay_seconds'])
location_state = set_location_input(driver, cell_input['location'], delay_seconds=cell_input['delay_seconds'])
search_state = click_search_button(driver, delay_seconds=cell_input['delay_seconds'])
print(json.dumps({'keyword': keyword_state, 'location': location_state, 'search': search_state}, indent=2))

# %%
import importlib
import browser.linkedin_jobs as linkedin_jobs

linkedin_jobs = importlib.reload(linkedin_jobs)

import json

from browser.linkedin_jobs import open_all_filters_menu, read_filters_state

# Open filters and read the current state.
cell_input_json = r'''
{
  "open_filters": true,
  "delay_seconds": 1.0
}
'''

cell_input = json.loads(cell_input_json)
if cell_input.get('open_filters'):
    print(json.dumps(open_all_filters_menu(driver, delay_seconds=cell_input['delay_seconds']), indent=2))
    time.sleep(cell_input['delay_seconds'])
current_filters = read_filters_state(driver, ensure_open=not cell_input.get('open_filters'))
print(json.dumps(current_filters, indent=2))

# %%
import importlib
import browser.linkedin_jobs as linkedin_jobs

linkedin_jobs = importlib.reload(linkedin_jobs)

import json

from browser.linkedin_jobs import sync_filters_state

# Sync filter choices.
cell_input_json = r'''
{
  "filter_by": "Jobs",
  "filters": [
    {
      "section": "Sort by",
      "type": "radio",
      "input": "Most recent"
    },
    {
      "section": "Date posted",
      "type": "radio",
      "input": "Past week"
    },
    {
      "section": "Experience level",
      "type": "checkbox",
      "inputs": [
        {"name": "Entry level", "state": true}
      ]
    }
  ],
  "delay_seconds": 0.2
}
'''

cell_input = json.loads(cell_input_json)
synced_filters = sync_filters_state(driver, cell_input, delay_seconds=cell_input['delay_seconds'])
print(json.dumps(synced_filters, indent=2))

# %%
import importlib
import browser.linkedin_jobs as linkedin_jobs

linkedin_jobs = importlib.reload(linkedin_jobs)

import json

from browser.linkedin_jobs import show_results

# Apply filters.
cell_input_json = r'''
{
  "apply_filters": true,
  "delay_seconds": 1.0
}
'''

cell_input = json.loads(cell_input_json)
if cell_input.get('apply_filters'):
    print(json.dumps(show_results(driver, delay_seconds=cell_input['delay_seconds']), indent=2))

# %%
import importlib
import browser.linkedin_jobs as linkedin_jobs

linkedin_jobs = importlib.reload(linkedin_jobs)

import json

from browser.linkedin_jobs import extract_listings

# Read listings.
cell_input_json = r'''
{
  "read_listings": true
}
'''

cell_input = json.loads(cell_input_json)
if cell_input.get('read_listings'):
    listings = extract_listings(driver)
    print(json.dumps(listings, indent=2))

# %%
# Read one listing detail.
import importlib
import browser.linkedin_jobs as linkedin_jobs
import parsers.listing_detail as listing_detail_parser
import stages.listing_detail as listing_detail

linkedin_jobs = importlib.reload(linkedin_jobs)
listing_detail_parser = importlib.reload(listing_detail_parser)
listing_detail = importlib.reload(listing_detail)

import json

from stages.listing_detail import extract_listing_detail

cell_input_json = r'''
{
  "index": 8,
  "delay_seconds": 1.0,
  "delay_jitter": 0.2
}
'''

cell_input = json.loads(cell_input_json)
detail_result = extract_listing_detail(
    driver,
    listings,
    index=cell_input["index"],
    delay_seconds=cell_input["delay_seconds"],
    delay_jitter=cell_input["delay_jitter"],
)
print(json.dumps(detail_result, indent=2, ensure_ascii=False))

# %%
# Convert the current page to markdown.
import importlib
import parsers.page_markdown as page_markdown
import browser.markdown as markdown_tools
page_markdown = importlib.reload(page_markdown)
markdown_tools = importlib.reload(markdown_tools)
import json
from browser.markdown import output_markdown

cell_input_json = r'''
{
  "preview_chars": 600000000
}
'''

cell_input = json.loads(cell_input_json)
markdown_text, interactables = output_markdown(driver)
print(markdown_text[:cell_input["preview_chars"]])
# print(json.dumps(interactables, indent=2, ensure_ascii=False))

# %%
# Test an interaction diff from the current markdown output.
from importlib import import_module, reload

interact_tools = import_module("browser.interact")
interact_tools = reload(interact_tools)

import json

cell_input_json = r'''
{
  "interaction_type": "click",
  "target_id": "i21",
  "delay_seconds": 3
}
'''

cell_input = json.loads(cell_input_json)
interaction_result = interact_tools.interact(
    driver,
    markdown_text,
    interactables,
    cell_input["interaction_type"],
    cell_input["target_id"],
    delay_seconds=cell_input["delay_seconds"],
)
print(json.dumps(interaction_result, indent=2, ensure_ascii=False))

# %%
# Test an interaction diff from the current markdown output.
from importlib import import_module, reload
import json

interact_tools = import_module("browser.interact")
interact_tools = reload(interact_tools)

cell_input_json = r'''
{
  "interaction_type": "input_text",
  "target_id": "t7?value=cheap%20vps",
  "delay_seconds": 1
}
'''

cell_input = json.loads(cell_input_json)
interaction_result = interact_tools.interact(
    driver,
    markdown_text,
    interactables,
    cell_input["interaction_type"],
    cell_input["target_id"],
    delay_seconds=cell_input["delay_seconds"],
)
print(json.dumps(interaction_result, indent=2, ensure_ascii=False))

# %%
# Test an interaction diff from the current markdown output.
from importlib import import_module, reload

interact_tools = import_module("browser.interact")
interact_tools = reload(interact_tools)

import json

cell_input_json = r'''
{
  "interaction_type": "input_text",
  "target_id": "i3?value=engineer",
  "delay_seconds": 1
}
'''

cell_input = json.loads(cell_input_json)
interaction_result = interact_tools.interact(
    driver,
    markdown_text,
    interactables,
    cell_input["interaction_type"],
    cell_input["target_id"],
    delay_seconds=cell_input["delay_seconds"],
)
print(json.dumps(interaction_result, indent=2, ensure_ascii=False))

# %%
import importlib
import browser.linkedin_jobs as linkedin_jobs

linkedin_jobs = importlib.reload(linkedin_jobs)

import json

from browser.linkedin_jobs import get_visible_pages

# Read pagination state.
cell_input_json = r'''
{
  "read_pages": true
}
'''

cell_input = json.loads(cell_input_json)
if cell_input.get('read_pages'):
    pages = get_visible_pages(driver)
    print(json.dumps({'pages': pages['pages']}, indent=2))

# %%
import importlib
import browser.linkedin_jobs as linkedin_jobs

linkedin_jobs = importlib.reload(linkedin_jobs)

import json

from browser.linkedin_jobs import get_current_page, go_to_page

# Go to a page and verify the current page.
cell_input_json = r'''
{
  "page": 2,
  "delay_seconds": 1.0
}
'''

cell_input = json.loads(cell_input_json)
print(json.dumps(go_to_page(driver, cell_input['page'], delay_seconds=cell_input['delay_seconds']), indent=2))
print(json.dumps(get_current_page(driver), indent=2))

# %%
import importlib
import browser.driver as browser_driver

browser_driver = importlib.reload(browser_driver)

import json

from browser.driver import close_driver

# Close browser.
cell_input_json = r'''
{
  "close_driver": true
}
'''

cell_input = json.loads(cell_input_json)
if cell_input.get('close_driver'):
    close_driver(driver)
    print(json.dumps({'status': 'Driver closed.'}, indent=2))
